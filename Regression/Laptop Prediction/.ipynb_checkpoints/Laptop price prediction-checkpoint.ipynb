# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('data.csv')
dfOriginal=df.copy() #copying original dataset to the dfOriginal
df
# Out:
#      Company            TypeName  Ram  Weight      Price  TouchScreen  Ips  \
# 0      Apple           Ultrabook    8    1.37  11.175755            0    1
# 1      Apple           Ultrabook    8    1.34  10.776777            0    0
# 2         HP            Notebook    8    1.86  10.329931            0    0
# 3      Apple           Ultrabook   16    1.83  11.814476            0    1
# 4      Apple           Ultrabook    8    1.37  11.473101            0    1
# ...      ...                 ...  ...     ...        ...          ...  ...
# 1268    Asus            Notebook    4    2.20  10.555257            0    0
# 1269  Lenovo  2 in 1 Convertible    4    1.80  10.433899            1    1
# 1270  Lenovo  2 in 1 Convertible   16    1.30  11.288115            1    1
# 1271  Lenovo            Notebook    2    1.50   9.409283            0    0
# 1272      HP            Notebook    6    2.19  10.614129            0    0
#
# ...

# %%
dfOriginal
# Out:
#      Company            TypeName  Ram  Weight      Price  TouchScreen  Ips  \
# 0      Apple           Ultrabook    8    1.37  11.175755            0    1
# 1      Apple           Ultrabook    8    1.34  10.776777            0    0
# 2         HP            Notebook    8    1.86  10.329931            0    0
# 3      Apple           Ultrabook   16    1.83  11.814476            0    1
# 4      Apple           Ultrabook    8    1.37  11.473101            0    1
# ...      ...                 ...  ...     ...        ...          ...  ...
# 1268    Asus            Notebook    4    2.20  10.555257            0    0
# 1269  Lenovo  2 in 1 Convertible    4    1.80  10.433899            1    1
# 1270  Lenovo  2 in 1 Convertible   16    1.30  11.288115            1    1
# 1271  Lenovo            Notebook    2    1.50   9.409283            0    0
# 1272      HP            Notebook    6    2.19  10.614129            0    0
#
# ...

# %%
df.shape
# Out:
# (1273, 13)

# %%
df.columns #all the columns in the dataset
# Out:
# Index(['Company', 'TypeName', 'Ram', 'Weight', 'Price', 'TouchScreen', 'Ips',
#        'Ppi', 'Cpu_brand', 'HDD', 'SSD', 'Gpu_brand', 'Os'],
#       dtype='object')

# %%
df.info() #checking data types
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1273 entries, 0 to 1272
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Company      1273 non-null   object
#  1   TypeName     1273 non-null   object
#  2   Ram          1273 non-null   int64
#  3   Weight       1273 non-null   float64
#  4   Price        1273 non-null   float64
#  5   TouchScreen  1273 non-null   int64
#  6   Ips          1273 non-null   int64
#  7   Ppi          1273 non-null   float64
#  8   Cpu_brand    1273 non-null   object
#  9   HDD          1273 non-null   int64
#  10  SSD          1273 non-null   int64
#  11  Gpu_brand    1273 non-null   object
#  12  Os           1273 non-null   object
# dtypes: float64(3), int64(5), object(5)
# memory usage: 129.4+ KB

# %%
df.isnull().sum() #checking null values
# Out:
# Company        0
# TypeName       0
# Ram            0
# Weight         0
# Price          0
# TouchScreen    0
# Ips            0
# Ppi            0
# Cpu_brand      0
# HDD            0
# SSD            0
# Gpu_brand      0
# Os             0
# dtype: int64

# %%
df.Company.unique() #checking unique values in column company
# Out:
# array(['Apple', 'HP', 'Acer', 'Asus', 'Dell', 'Lenovo', 'Chuwi', 'MSI',
#        'Microsoft', 'Toshiba', 'Huawei', 'Xiaomi', 'Vero', 'Razer',
#        'Mediacom', 'Samsung', 'Google', 'Fujitsu', 'LG'], dtype=object)

# %%
for i in df.columns: #checking unique values in all columns
    print(f'i,Feature Name: {i}')
    print('-----------------------------------------')
    print(f'Unique Values : {df[i].unique()}')
    print('-----------------------------------------')
# Out:
# i,Feature Name: Company
# -----------------------------------------
# Unique Values : ['Apple' 'HP' 'Acer' 'Asus' 'Dell' 'Lenovo' 'Chuwi' 'MSI' 'Microsoft'
#  'Toshiba' 'Huawei' 'Xiaomi' 'Vero' 'Razer' 'Mediacom' 'Samsung' 'Google'
#  'Fujitsu' 'LG']
# -----------------------------------------
# i,Feature Name: TypeName
# -----------------------------------------
# Unique Values : ['Ultrabook' 'Notebook' 'Netbook' 'Gaming' '2 in 1 Convertible'
#  'Workstation']
# -----------------------------------------
# i,Feature Name: Ram
# -----------------------------------------
# Unique Values : [ 8 16  4  2 12  6 32 24 64]
# -----------------------------------------
# i,Feature Name: Weight
# -----------------------------------------
# Unique Values : [1.37  1.34  1.86  1.83  2.1   2.04  1.3   1.6   2.2   0.92  1.22  0.98
#  2.5   1.62  1.91  2.3   1.35  1.88  1.89  1.65  2.71  1.2   1.44  2.8
#  2.    2.65  2.77  3.2   0.69  1.49  2.4   2.13  2.43  1.7   1.4   1.8
# ...

# %%
print('Categorical Features in the dataset')
for i in df.columns:
    if(df[i].dtypes=='O'):
        print(i)
# Out:
# Categorical Features in the dataset
# Company
# TypeName
# Cpu_brand
# Gpu_brand
# Os

# %%
df.describe()
# Out:
#                Ram       Weight        Price  TouchScreen          Ips  \
# count  1273.000000  1273.000000  1273.000000  1273.000000  1273.000000
# mean      8.447761     2.041100    10.828218     0.146897     0.279654
# std       5.098771     0.669241     0.619565     0.354142     0.449006
# min       2.000000     0.690000     9.134616     0.000000     0.000000
# 25%       4.000000     1.500000    10.387379     0.000000     0.000000
# 50%       8.000000     2.040000    10.872255     0.000000     0.000000
# 75%       8.000000     2.310000    11.287447     0.000000     1.000000
# max      64.000000     4.700000    12.691441     1.000000     1.000000
#
#                Ppi          HDD          SSD
# count  1273.000000  1273.000000  1273.000000
# mean    146.950812   413.715632   186.252946
# std      42.926775   518.054486   186.531571
# min      90.583402     0.000000     0.000000
# 25%     127.335675     0.000000     0.000000
# 50%     141.211998     0.000000   256.000000
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
df['Os']=le.fit_transform(df['Os'])

# %%
df.Os.dtype
# Out:
# dtype('int32')

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
for col in df.columns:
    if df[col].dtype == 'O':  # Ensure the column is of object type before transforming
         df[col] = le.fit_transform(df[col])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1273 entries, 0 to 1272
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Company      1273 non-null   int32
#  1   TypeName     1273 non-null   int32
#  2   Ram          1273 non-null   int64
#  3   Weight       1273 non-null   float64
#  4   Price        1273 non-null   float64
#  5   TouchScreen  1273 non-null   int64
#  6   Ips          1273 non-null   int64
#  7   Ppi          1273 non-null   float64
#  8   Cpu_brand    1273 non-null   int32
#  9   HDD          1273 non-null   int64
#  10  SSD          1273 non-null   int64
#  11  Gpu_brand    1273 non-null   int32
#  12  Os           1273 non-null   int32
# dtypes: float64(3), int32(5), int64(5)
# memory usage: 104.6 KB

# %%
df.corr()
# Out:
#               Company  TypeName       Ram    Weight     Price  TouchScreen  \
# Company      1.000000  0.005373  0.042571 -0.126177  0.138395     0.025781
# TypeName     0.005373  1.000000 -0.244020 -0.278346 -0.125212    -0.404706
# Ram          0.042571 -0.244020  1.000000  0.389134  0.680519     0.113316
# Weight      -0.126177 -0.278346  0.389134  1.000000  0.151386    -0.292288
# Price        0.138395 -0.125212  0.680519  0.151386  1.000000     0.194289
# TouchScreen  0.025781 -0.404706  0.113316 -0.292288  0.194289     1.000000
# Ips          0.109680 -0.154569  0.202809  0.023966  0.279240     0.136973
# Ppi          0.064264 -0.028490  0.294927 -0.319499  0.480687     0.452107
# Cpu_brand    0.019956 -0.121850  0.244028 -0.053179  0.201990     0.129662
# HDD         -0.126544 -0.199795  0.097340  0.510876 -0.097361    -0.205105
# SSD          0.126847 -0.073101  0.599552 -0.056985  0.658808     0.252142
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
corr_matrix = df.corr()

# %%
# Plot the correlation matrix using seaborn with enhanced visualization
plt.figure(figsize=(20,15))  # Increase figure size for better readability
sns.set(font_scale=1.2)  # Increase the font scale for better readability
heatmap = sns.heatmap(
    corr_matrix, 
    annot=True, 
    cmap='YlGnBu',  # Changed the color map to 'YlGnBu' for a different look
    fmt='.2f', 
    vmin=-1, 
    vmax=1, 
    linewidths=.5,  # Add grid lines for better separation
    cbar_kws={"shrink": .8}  # Shrink the color bar for better aesthetics
)
heatmap.set_xticklabels(heatmap.get_xticklabels(), rotation=45, horizontalalignment='right')
heatmap.set_yticklabels(heatmap.get_yticklabels(), rotation=0)
plt.title('Correlation Matrix', fontsize=20)
plt.show()

# %%
sns.pairplot(data=df,hue='Price')
# Out:
# C:\Users\DELL\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\seaborn\axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(12,8))
sns.boxplot(x="Company", y="Price", data=dfOriginal)
plt.xlabel('Company')
plt.ylabel('Laptop Price')
plt.title('laptop price by company')
plt.xticks(rotation=45)
plt.show()

# %%
# Violin plot of laptop prices by company
plt.figure(figsize=(12, 8))
sns.violinplot(x='Company', y='Price', data=dfOriginal)
plt.title('Laptop Price by Company')
plt.xticks(rotation=45)
plt.show()

# %%
# Bar plot of average laptop price by company
plt.figure(figsize=(12, 8))
avg_price_by_company = dfOriginal.groupby('Company')['Price'].mean().reset_index()
sns.barplot(x='Company', y='Price', data=avg_price_by_company)
plt.title('Average Laptop Price by Company')
plt.xticks(rotation=45)
plt.show()

# %%
# Swarm plot of laptop prices by company
plt.figure(figsize=(12, 8))
sns.swarmplot(x='Company', y='Price', data=dfOriginal)
plt.title('Laptop Price by Company')
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\seaborn\categorical.py:3399: UserWarning:
#
# 30.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#
# C:\Users\DELL\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\seaborn\categorical.py:3399: UserWarning:
#
# 7.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#
# C:\Users\DELL\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\seaborn\categorical.py:3399: UserWarning:
#
# 11.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#
# ...

# %%
dfOriginal
# Out:
#      Company            TypeName  Ram  Weight      Price  TouchScreen  Ips  \
# 0      Apple           Ultrabook    8    1.37  11.175755            0    1
# 1      Apple           Ultrabook    8    1.34  10.776777            0    0
# 2         HP            Notebook    8    1.86  10.329931            0    0
# 3      Apple           Ultrabook   16    1.83  11.814476            0    1
# 4      Apple           Ultrabook    8    1.37  11.473101            0    1
# ...      ...                 ...  ...     ...        ...          ...  ...
# 1268    Asus            Notebook    4    2.20  10.555257            0    0
# 1269  Lenovo  2 in 1 Convertible    4    1.80  10.433899            1    1
# 1270  Lenovo  2 in 1 Convertible   16    1.30  11.288115            1    1
# 1271  Lenovo            Notebook    2    1.50   9.409283            0    0
# 1272      HP            Notebook    6    2.19  10.614129            0    0
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Calculate average price by company
avg_price_by_company = dfOriginal.groupby('Company')['Price'].mean().reset_index()

# Create subplots: 2 rows, 3 columns
fig, axes = plt.subplots(2, 3, figsize=(50, 25))

# Box Plot
sns.boxplot(data=dfOriginal, x='Company', y='Price', ax=axes[0, 0])
axes[0, 0].set_title('Box Plot of Laptop Prices by Company')

# Violin Plot
sns.violinplot(data=dfOriginal, x='Company', y='Price', ax=axes[0, 1])
axes[0, 1].set_title('Violin Plot of Laptop Prices by Company')

# Bar Plot of Average Prices
sns.barplot(data=avg_price_by_company, x='Company', y='Price', ax=axes[0, 2])
axes[0, 2].set_title('Bar Plot of Average Laptop Prices by Company')

# Histogram of Prices
sns.histplot(data=dfOriginal, x='Price', ax=axes[1, 0])
axes[1, 0].set_title('Histogram of Laptop Prices')

# Scatter Plot of Ram vs Price
sns.scatterplot(data=dfOriginal, x='Ram', y='Price', hue='Company', ax=axes[1, 1])
axes[1, 1].set_title('Scatter Plot of Ram vs Price')

# Line Plot of Average Price over Companies
sns.lineplot(data=avg_price_by_company, x='Company', y='Price', ax=axes[1, 2])
axes[1, 2].set_title('Line Plot of Average Laptop Prices by Company')

# Adjust layout
plt.tight_layout()
plt.suptitle("Various Plots of Laptop Prices by Company", y=1.02, fontsize=20)

# Show the figure in Jupyter Notebook
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


# Compute the correlation matrix
correlation_matrix = df.corr()

# Set up the matplotlib figure
plt.figure(figsize=(16, 12))

# Create the heatmap with annotations
heatmap = sns.heatmap(
    correlation_matrix, 
    annot=True, 
    fmt=".2f", 
    cmap='viridis', 
    cbar_kws={'shrink': .8}, 
    linewidths=1, 
    linecolor='black', 
    annot_kws={"size": 12}
)

# Adjust the font size for the axes
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)

# Set the title
plt.title('Heatmap of Feature Correlations', fontsize=24, pad=20)

# Show the figure
plt.show()
