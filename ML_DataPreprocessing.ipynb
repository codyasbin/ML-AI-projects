# %%
import pandas as pd
df=pd.read_csv('index.csv')
df
# Out:
#            date                 datetime cash_type                 card  \
# 0    2024-03-01  2024-03-01 10:15:50.520      card  ANON-0000-0000-0001
# 1    2024-03-01  2024-03-01 12:19:22.539      card  ANON-0000-0000-0002
# 2    2024-03-01  2024-03-01 12:20:18.089      card  ANON-0000-0000-0002
# 3    2024-03-01  2024-03-01 13:46:33.006      card  ANON-0000-0000-0003
# 4    2024-03-01  2024-03-01 13:48:14.626      card  ANON-0000-0000-0004
# ..          ...                      ...       ...                  ...
# 971  2024-07-14  2024-07-14 22:31:29.976      card  ANON-0000-0000-0376
# 972  2024-07-15  2024-07-15 07:33:05.557      card  ANON-0000-0000-0377
# 973  2024-07-16  2024-07-16 12:23:37.467      card  ANON-0000-0000-0378
# 974  2024-07-16  2024-07-16 19:29:25.485      card  ANON-0000-0000-0367
# 975  2024-07-17  2024-07-17 13:04:59.744      card  ANON-0000-0000-0379
#
#      money          coffee_name
# 0    38.70                Latte
# 1    38.70        Hot Chocolate
# ...

# %%
#checking data types of the values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 976 entries, 0 to 975
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         976 non-null    object
#  1   datetime     976 non-null    object
#  2   cash_type    976 non-null    object
#  3   card         887 non-null    object
#  4   money        976 non-null    float64
#  5   coffee_name  976 non-null    object
# dtypes: float64(1), object(5)
# memory usage: 45.9+ KB

# %%
df.isnull().sum() #checking null values
# Out:
# date            0
# datetime        0
# cash_type       0
# card           89
# money           0
# coffee_name     0
# dtype: int64

# %%
df[['money']] #displaying value of column card in dataframe
# Out:
#      money
# 0    38.70
# 1    38.70
# 2    38.70
# 3    28.90
# 4    38.70
# ..     ...
# 971  32.82
# 972  32.82
# 973  27.92
# 974  32.82
# 975  27.92
#
# [976 rows x 1 columns]

# %%
df.card #displaying value of column card
# Out:
# 0      ANON-0000-0000-0001
# 1      ANON-0000-0000-0002
# 2      ANON-0000-0000-0002
# 3      ANON-0000-0000-0003
# 4      ANON-0000-0000-0004
#               ...
# 971    ANON-0000-0000-0376
# 972    ANON-0000-0000-0377
# 973    ANON-0000-0000-0378
# 974    ANON-0000-0000-0367
# 975    ANON-0000-0000-0379
# Name: card, Length: 976, dtype: object

# %%
df.money.unique() #finding the unique values
# Out:
# array([38.7 , 28.9 , 33.8 , 40.  , 24.  , 35.  , 30.  , 25.  , 32.82,
#        39.  , 37.72, 27.92, 29.  , 34.  , 23.02])

# %%
for i in df.columns:
    print(i,"\n------------------")
    print(df[i].unique())
    print(f"The total number of unique values are: {len(df[i].unique())}\n")
# Out:
# date
# ------------------
# ['2024-03-01' '2024-03-02' '2024-03-03' '2024-03-04' '2024-03-05'
#  '2024-03-06' '2024-03-07' '2024-03-08' '2024-03-09' '2024-03-10'
#  '2024-03-11' '2024-03-12' '2024-03-13' '2024-03-14' '2024-03-15'
#  '2024-03-16' '2024-03-17' '2024-03-18' '2024-03-19' '2024-03-20'
#  '2024-03-21' '2024-03-22' '2024-03-23' '2024-03-24' '2024-03-25'
#  '2024-03-26' '2024-03-27' '2024-03-28' '2024-03-29' '2024-03-30'
#  '2024-03-31' '2024-04-01' '2024-04-02' '2024-04-03' '2024-04-04'
#  '2024-04-05' '2024-04-06' '2024-04-07' '2024-04-08' '2024-04-09'
#  '2024-04-10' '2024-04-11' '2024-04-12' '2024-04-13' '2024-04-14'
#  '2024-04-15' '2024-04-16' '2024-04-17' '2024-04-18' '2024-04-19'
#  '2024-04-20' '2024-04-21' '2024-04-22' '2024-04-23' '2024-04-24'
#  '2024-04-25' '2024-04-26' '2024-04-27' '2024-04-28' '2024-04-29'
#  '2024-04-30' '2024-05-02' '2024-05-03' '2024-05-06' '2024-05-07'
#  '2024-05-08' '2024-05-09' '2024-05-10' '2024-05-11' '2024-05-12'
# ...

# %%
df.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 df.corr()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\frame.py:10054, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10052 cols = data.columns
#   10053 idx = cols.copy()
# > 10054 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10056 if method == "pearson":
#   10057     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\frame.py:1838, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1836 if dtype is not None:
#    1837     dtype = np.dtype(dtype)
# ...
